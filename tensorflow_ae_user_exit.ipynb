# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Data** **Pre** **Processing**

# %% [markdown]
# Importing the data

# %%
data= pd.read_excel("ae_user_exit.xlsx")

# %%
data.head(10)
# Out:
#    Credit Score  Geography  Gender  Age  Customer Since  Current Account  \
# 0           553      Delhi  Female   45               4            0.000
# 1           447  Bengaluru    Male   31               7            0.000
# 2           501      Delhi  Female   32               2            0.000
# 3           428      Delhi    Male   51               3            0.000
# 4           492      Delhi  Female   57               6      1912681.501
# 5           649     Mumbai    Male   61               4      1739005.126
# 6           624     Mumbai    Male   54               6      1741981.923
# 7           510  Bengaluru    Male   74               8            0.000
# 8           573     Mumbai    Male   45               8      1245561.866
# 9           517      Delhi  Female   62               6      2210750.266
#
#    Num of products  UPI Enabled  Estimated Yearly Income  Closed
# 0                4            1                   274150       0
# 1                4            1                   519360       0
# 2                4            1                   545501       0
# 3                4            1                    86868       0
# 4                2            1                   518680       0
# 5                2            1                    86816       1
# 6                4            1                    72959       1
# 7                4            1                   295115       0
# 8                4            1                   471174       1
# 9                4            0                   149488       1

# %%
data.tail()
# Out:
#       Credit Score  Geography  Gender  Age  Customer Since  Current Account  \
# 9922           594  Bengaluru    Male   28               6     0.000000e+00
# 9923           557  Bengaluru    Male   59               3     8.050490e+05
# 9924           627     Mumbai  Female   42               4     1.893594e+06
# 9925           600  Bengaluru  Female   51               0     9.031778e+05
# 9926           553      Delhi    Male   75               7     0.000000e+00
#
#       Num of products  UPI Enabled  Estimated Yearly Income  Closed
# 9922                4            1                   394810       0
# 9923                2            0                    58163       1
# 9924                4            0                   494067       0
# 9925                2            1                   109375       1
# 9926                4            1                   180031       0

# %%
x= data.iloc[:, :-1].values
y= data.iloc[:, -1].values

# %%
x
# Out:
# array([[553, 'Delhi', 'Female', ..., 4, 1, 274150],
#        [447, 'Bengaluru', 'Male', ..., 4, 1, 519360],
#        [501, 'Delhi', 'Female', ..., 4, 1, 545501],
#        ...,
#        [627, 'Mumbai', 'Female', ..., 4, 0, 494067],
#        [600, 'Bengaluru', 'Female', ..., 2, 1, 109375],
#        [553, 'Delhi', 'Male', ..., 4, 1, 180031]], dtype=object)

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %% [markdown]
# Handling missing data

# %%
from sklearn.impute import SimpleImputer

# %%
imputer= SimpleImputer(missing_values= np.nan, strategy= 'mean')

# %%
imputer.fit(x[:, 0:1])
#handling missing values in the credit column only as it is our main column (also data doesn't contain any missing values)
# Out:
# SimpleImputer()

# %%
x[:, 0:1]= imputer.fit_transform(x[:, 0:1])

# %%
x
# Out:
# array([[553.0, 'Delhi', 'Female', ..., 4, 1, 274150],
#        [447.0, 'Bengaluru', 'Male', ..., 4, 1, 519360],
#        [501.0, 'Delhi', 'Female', ..., 4, 1, 545501],
#        ...,
#        [627.0, 'Mumbai', 'Female', ..., 4, 0, 494067],
#        [600.0, 'Bengaluru', 'Female', ..., 2, 1, 109375],
#        [553.0, 'Delhi', 'Male', ..., 4, 1, 180031]], dtype=object)

# %% [markdown]
# encoding categorical data into numeric data

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

# %%
x[0,:]
# Out:
# array([553.0, 'Delhi', 'Female', 45, 4, 0.0, 4, 1, 274150], dtype=object)

# %%
le= LabelEncoder() #label encoder to convert gender col into 0/1 form (as it was binary categorical data)

# %%
x[:, 2]= le.fit_transform(x[:, 2])

# %%
x[0,:]
# Out:
# array([553.0, 'Delhi', 0, 45, 4, 0.0, 4, 1, 274150], dtype=object)

# %%
ct= ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder= 'passthrough') #one hot encoding on city as it is categorical data (more than 2 categories)

# %%
x= np.array(ct.fit_transform(x))

# %%
x
# Out:
# array([[0.0, 1.0, 0.0, ..., 4, 1, 274150],
#        [1.0, 0.0, 0.0, ..., 4, 1, 519360],
#        [0.0, 1.0, 0.0, ..., 4, 1, 545501],
#        ...,
#        [0.0, 0.0, 1.0, ..., 4, 0, 494067],
#        [1.0, 0.0, 0.0, ..., 2, 1, 109375],
#        [0.0, 1.0, 0.0, ..., 4, 1, 180031]], dtype=object)

# %%
x.shape
# Out:
# (9927, 11)

# %%
x[0,:]
# Out:
# array([0.0, 1.0, 0.0, 553.0, 0, 45, 4, 0.0, 4, 1, 274150], dtype=object)

# %% [markdown]
# data splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y,test_size=0.2, random_state=0)

# %%
x_train
# Out:
# array([[1.0, 0.0, 0.0, ..., 4, 1, 264201],
#        [0.0, 0.0, 1.0, ..., 4, 1, 328575],
#        [1.0, 0.0, 0.0, ..., 2, 0, 168958],
#        ...,
#        [0.0, 0.0, 1.0, ..., 2, 1, 248115],
#        [0.0, 0.0, 1.0, ..., 2, 1, 499155],
#        [1.0, 0.0, 0.0, ..., 2, 0, 10454]], dtype=object)

# %%
x_test
# Out:
# array([[0.0, 0.0, 1.0, ..., 2, 1, 502959],
#        [0.0, 0.0, 1.0, ..., 4, 1, 80970],
#        [1.0, 0.0, 0.0, ..., 4, 1, 2568],
#        ...,
#        [1.0, 0.0, 0.0, ..., 4, 0, 294987],
#        [1.0, 0.0, 0.0, ..., 2, 0, 180942],
#        [1.0, 0.0, 0.0, ..., 2, 1, 538471]], dtype=object)

# %%
y_train
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
y_test
# Out:
# array([1, 0, 0, ..., 1, 0, 1])

# %%
print(f'train shape: {x_train.shape}\n test shape: {x_test.shape}')
# Out:
# train shape: (7941, 11)
#  test shape: (1986, 11)

# %% [markdown]
# feature scaling

# %%
#scaling all the data of the data in a comparable range
from sklearn.preprocessing import StandardScaler
scale= StandardScaler()

# %%
x_train = scale.fit_transform(x_train) #train data is first fit and then transformed
x_test = scale.transform(x_test) #test data is directly transformed

# %%
x_train #scaled into a comparable ranges
# Out:
# array([[ 0.99434917, -0.57109746, -0.5792406 , ...,  0.90580857,
#          0.65086753, -0.06854301],
#        [-1.00568294, -0.57109746,  1.72639831, ...,  0.90580857,
#          0.65086753,  0.34018176],
#        [ 0.99434917, -0.57109746, -0.5792406 , ..., -0.951175  ,
#         -1.53641095, -0.67326188],
#        ...,
#        [-1.00568294, -0.57109746,  1.72639831, ..., -0.951175  ,
#          0.65086753, -0.17067658],
#        [-1.00568294, -0.57109746,  1.72639831, ..., -0.951175  ,
#          0.65086753,  1.4232319 ],
#        [ 0.99434917, -0.57109746, -0.5792406 , ..., -0.951175  ,
#         -1.53641095, -1.67963883]])

# %%
y_train = y_train.reshape(-1, 1)

# %%
y_train.shape
# Out:
# (7941, 1)

# %% [markdown]
# # **ANN implementation**

# %% [markdown]
# Initialization

# %%
#initializing neural network
ann= tf.keras.models.Sequential()

# %% [markdown]
# adding layers to the neural network

# %%
ann.add(tf.keras.layers.Dense(units=5, activation='relu')) #for first layer we will use 5 nodes and relu as the activation function

# %%
ann.add(tf.keras.layers.Dense(units=5, activation='relu')) #for the next hidden layer we will use the same metrics

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid')) #for the final output layer we will use single node but sigmoid activation function as it helps us to classify the y-hat in range of 0-1

# %% [markdown]
# compiling the nn

# %%
ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
ann.fit(x_train, y_train, batch_size=32, epochs=120)
# Out:
# Epoch 1/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5985 - loss: 0.6846
# Epoch 2/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7930 - loss: 0.5173
# Epoch 3/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7929 - loss: 0.4738
# Epoch 4/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7953 - loss: 0.4392
# Epoch 5/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7916 - loss: 0.4340
# Epoch 6/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8165 - loss: 0.4129
# Epoch 7/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8196 - loss: 0.4032
# Epoch 8/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8279 - loss: 0.3974
# Epoch 9/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8326 - loss: 0.3843
# Epoch 10/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8342 - loss: 0.3804
# Epoch 11/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8304 - loss: 0.3891
# Epoch 12/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8302 - loss: 0.3840
# Epoch 13/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8276 - loss: 0.3829
# Epoch 14/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8363 - loss: 0.3705
# Epoch 15/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8351 - loss: 0.3797
# Epoch 16/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8434 - loss: 0.3687
# Epoch 17/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8452 - loss: 0.3674
# Epoch 18/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8488 - loss: 0.3706
# Epoch 19/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8513 - loss: 0.3583
# Epoch 20/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8444 - loss: 0.3731
# Epoch 21/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8469 - loss: 0.3651
# Epoch 22/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8466 - loss: 0.3612
# Epoch 23/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8466 - loss: 0.3649
# Epoch 24/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8459 - loss: 0.3614
# Epoch 25/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8473 - loss: 0.3615
# Epoch 26/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8444 - loss: 0.3740
# Epoch 27/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8558 - loss: 0.3546
# Epoch 28/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8405 - loss: 0.3747
# Epoch 29/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8516 - loss: 0.3534
# Epoch 30/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8512 - loss: 0.3518
# Epoch 31/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8466 - loss: 0.3655
# Epoch 32/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.3502
# Epoch 33/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8499 - loss: 0.3595
# Epoch 34/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8567 - loss: 0.3449
# Epoch 35/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8464 - loss: 0.3629
# Epoch 36/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8534 - loss: 0.3473
# Epoch 37/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8495 - loss: 0.3579
# Epoch 38/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8509 - loss: 0.3569
# Epoch 39/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8490 - loss: 0.3551
# Epoch 40/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8592 - loss: 0.3434
# Epoch 41/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8527 - loss: 0.3477
# Epoch 42/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8555 - loss: 0.3527
# Epoch 43/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8443 - loss: 0.3618
# Epoch 44/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8460 - loss: 0.3497
# Epoch 45/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8472 - loss: 0.3554
# Epoch 46/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8480 - loss: 0.3554
# Epoch 47/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8502 - loss: 0.3506
# Epoch 48/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8447 - loss: 0.3597
# Epoch 49/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8499 - loss: 0.3538
# Epoch 50/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8487 - loss: 0.3497
# Epoch 51/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8513 - loss: 0.3595
# Epoch 52/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8490 - loss: 0.3495
# Epoch 53/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8549 - loss: 0.3430
# Epoch 54/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8571 - loss: 0.3418
# Epoch 55/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8523 - loss: 0.3585
# Epoch 56/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8505 - loss: 0.3524
# Epoch 57/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8539 - loss: 0.3536
# Epoch 58/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8552 - loss: 0.3409
# Epoch 59/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8515 - loss: 0.3542
# Epoch 60/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8556 - loss: 0.3507
# Epoch 61/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8517 - loss: 0.3508
# Epoch 62/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8539 - loss: 0.3484
# Epoch 63/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8521 - loss: 0.3559
# Epoch 64/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8558 - loss: 0.3439
# Epoch 65/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8567 - loss: 0.3430
# Epoch 66/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8554 - loss: 0.3563
# Epoch 67/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8544 - loss: 0.3557
# Epoch 68/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8523 - loss: 0.3539
# Epoch 69/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8503 - loss: 0.3547
# Epoch 70/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8513 - loss: 0.3514
# Epoch 71/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8454 - loss: 0.3596
# Epoch 72/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8464 - loss: 0.3572
# Epoch 73/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8515 - loss: 0.3549
# Epoch 74/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8519 - loss: 0.3477
# Epoch 75/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8487 - loss: 0.3558
# Epoch 76/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8539 - loss: 0.3474
# Epoch 77/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8507 - loss: 0.3497
# Epoch 78/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8531 - loss: 0.3541
# Epoch 79/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8524 - loss: 0.3473
# Epoch 80/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8562 - loss: 0.3447
# Epoch 81/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8505 - loss: 0.3499
# Epoch 82/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8578 - loss: 0.3431
# Epoch 83/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8522 - loss: 0.3502
# Epoch 84/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8531 - loss: 0.3442
# Epoch 85/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8603 - loss: 0.3411
# Epoch 86/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8528 - loss: 0.3436
# Epoch 87/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8510 - loss: 0.3510
# Epoch 88/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8572 - loss: 0.3443
# Epoch 89/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8578 - loss: 0.3437
# Epoch 90/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8444 - loss: 0.3594
# Epoch 91/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8514 - loss: 0.3507
# Epoch 92/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8538 - loss: 0.3433
# Epoch 93/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8479 - loss: 0.3546
# Epoch 94/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8575 - loss: 0.3383
# Epoch 95/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8503 - loss: 0.3530
# Epoch 96/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8548 - loss: 0.3496
# Epoch 97/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8525 - loss: 0.3552
# Epoch 98/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8466 - loss: 0.3685
# Epoch 99/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8500 - loss: 0.3581
# Epoch 100/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8506 - loss: 0.3509
# Epoch 101/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8572 - loss: 0.3387
# Epoch 102/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8564 - loss: 0.3369
# Epoch 103/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8543 - loss: 0.3474
# Epoch 104/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8527 - loss: 0.3482
# Epoch 105/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8607 - loss: 0.3417
# Epoch 106/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8607 - loss: 0.3440
# Epoch 107/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8497 - loss: 0.3519
# Epoch 108/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8587 - loss: 0.3409
# Epoch 109/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8550 - loss: 0.3477
# Epoch 110/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8516 - loss: 0.3500
# Epoch 111/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8497 - loss: 0.3525
# Epoch 112/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8530 - loss: 0.3451
# Epoch 113/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8521 - loss: 0.3526
# Epoch 114/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8517 - loss: 0.3502
# Epoch 115/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8563 - loss: 0.3420
# Epoch 116/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8481 - loss: 0.3502
# Epoch 117/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8540 - loss: 0.3369
# Epoch 118/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8543 - loss: 0.3494
# Epoch 119/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8575 - loss: 0.3436
# Epoch 120/120
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8501 - loss: 0.3534

# %% [markdown]
# **prediction**

# %%
y_pred= ann.predict(x_test)
y_pred= (y_pred > 0.5).astype(int)
y_pred.shape
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# (1986, 1)

# %%
y_test.reshape(-1, 1)
# Out:
# array([[1],
#        [0],
#        [0],
#        ...,
#        [1],
#        [0],
#        [1]])

# %%
m,_= y_pred.shape
for i in range(m):
  print(f'y_pred: {y_pred[i]} y_test: {y_test[i]}')
# Out:
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 0
# y_pred: [1] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1
# y_pred: [1] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 0
# y_pred: [0] y_test: 1
# y_pred: [0] y_test: 0
# y_pred: [1] y_test: 1

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm= confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[1499   74]
#  [ 222  191]]
# 0.850956696878147
